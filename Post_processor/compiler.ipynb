# %% [markdown]
# **Import required libraries here**

# %%
import numpy as np
import pandas as pd

import dask.dataframe as dd
import dask.array as da
import dask.bag as db

# %% [markdown]
# # 1. Loading twitter and domain data
#
# **Run the code below to:**
#
# Read twitter data csvs and domain data csvs and clean up the data. Then store them under `Saved` folder
# - Twitter data will be stored as parquet in `./Saved/twitter_data.parquet`
# - Domain data will be stored as parquet in `./Saved/domain_data.parquet`
#
# > *Code is under `/post_input/load_input.py`*

# %%
import post_input.load_input as load_input
# load domain and twitter data
load_input.load_twitter('./logs/*_output_*.csv') # change path to your twitter output csvs
load_input.load_domain('./DataDomain/*.csv') # change path to your domain output csvs
# Out:
# Skipping line 20: unexpected end of data

# %% [markdown]
# **You can view the saved data after loaded into post-processor**

# %%
# change to './Saved/domain_data.parquet' to view domain data
data = dd.read_parquet('./Saved/twitter_data.parquet') 
data.head(1)
# Out:
#                                                                                       id  \
# url
# https://www.nytimes.com/2002/04/25/aponline/tec...  b1beab0a-4bc6-540b-b578-6fe28c2e6aef
#
#                                                                                                 title  \
# url
# https://www.nytimes.com/2002/04/25/aponline/tec...  Article 2002042593816751672 -- No Title (Publi...
#
#                                                    author  \
# url
# https://www.nytimes.com/2002/04/25/aponline/tec...     By
#
#                                                                         date  \
# url
# https://www.nytimes.com/2002/04/25/aponline/tec...  2002-04-25T05:00:00.000Z
#
#                                                                                          html_content  \
# url
# https://www.nytimes.com/2002/04/25/aponline/tec...  <div id="readability-page-1" class="page"><art...
#
#                                                                                          article_text  \
# url
# https://www.nytimes.com/2002/04/25/aponline/tec...  April 25, 2002 The New York Times: APTechnolog...
#
#                                                                      domain  \
# url
# https://www.nytimes.com/2002/04/25/aponline/tec...  https://www.nytimes.com
#
#                                                                                            found_urls  \
# url
# https://www.nytimes.com/2002/04/25/aponline/tec...  [{'title': 'Skip to content', 'url': 'https://...
#
#                                                        type  completed
# url
# https://www.nytimes.com/2002/04/25/aponline/tec...  article      False

# %% [markdown]
# # 2. Post Processing
# **Run the code below to:**
#
# Finding and adding citations and text alias information with respect to citation scope.
# Finding and adding domain information with respect to crawl scope.
# Then Cross match between domain and twitter data to find referrals. Stored them under `Saved` folder
#
# - Note: This step is independent from step one as long as there is `./Saved/twitter_data.parquet` and `./Saved/domain_data.parquet`
# - Processed Twitter data will be stored as parquet in `./Saved/processed_twitter_data.parquet`
# - Processed Domain data will be stored as parquet in `./Saved/processed_domain_data.parquet`
#
# > *Code is under `/post_processor/*.py`*

# %%
# %%time
import post_processor.processor as processor
import post_input.load_input as load_input
# post process data
crawl_scope = load_input.load_scope('./crawl_scope.csv')
citation_scope = load_input.load_scope('./citation_scope.csv')
processor.process_crawler(crawl_scope, citation_scope)
# Out:
# CPU times: user 2min 56s, sys: 1.75 s, total: 2min 58s
# Wall time: 2min 57s

# %% [markdown]
# **You can view processed data here**

# %%
# change to './Saved/processed_domain_data.parquet' to view the domain data
df = dd.read_parquet('./Saved/processed_twitter_data.parquet')
df.head(1)
# Out:
#                                                        domain  \
# url
# https://twitter.com/ACMideast/status/1000009046...  ACMideast
#
#                                                                         date  \
# url
# https://twitter.com/ACMideast/status/1000009046... 2018-05-25 13:41:50+00:00
#
#                                                                                          article_text  \
# url
# https://twitter.com/ACMideast/status/1000009046...  دلالات الانتخابات المحلية التونسية \nhttps://t...
#
#                                                                                            found_urls  \
# url
# https://twitter.com/ACMideast/status/1000009046...  ['http://www.achariricenter.org/is-tunisias-gl...
#
#                                                    Mentions  \
# url
# https://twitter.com/ACMideast/status/1000009046...       []
#
#                                                                                       id  \
# url
# https://twitter.com/ACMideast/status/1000009046...  9af4a6a6-fbd8-5866-9b59-9850edf109a7
#
#                                                        type title  completed  \
# url
# https://twitter.com/ACMideast/status/1000009046...  twitter             True
#
#                                                    citation url or text alias  \
# url
# https://twitter.com/ACMideast/status/1000009046...                         []
#
#                                                    citation name anchor text  \
# url
# https://twitter.com/ACMideast/status/1000009046...            []          []
#
#                                                    associated publisher  \
# url
# https://twitter.com/ACMideast/status/1000009046...
#
#                                                                            tags  \
# url
# https://twitter.com/ACMideast/status/1000009046...  Think_Tank|||US|11-20||||||
#
#                                                                 name  \
# url
# https://twitter.com/ACMideast/status/1000009046...  Atlantic Council
#
#                                                    referring record id  \
# url
# https://twitter.com/ACMideast/status/1000009046...                  []
#
#                                                     number of referrals  \
# url
# https://twitter.com/ACMideast/status/1000009046...                    0
#
#                                                                                               url_dup
# url
# https://twitter.com/ACMideast/status/1000009046...  https://twitter.com/ACMideast/status/100000904...

# %% [markdown]
# # 3. Generate output
#
# **Run the cell below to:**
#
# Rename and clean up keys. Select rows with citations from **citation scope** and belongs to **crawl scope**. Then create output in `Output/output_0.csv` and also in `./Saved/final_output.parquet`.
#
# - Note: This step is independent from step one and two as long as there is `./Saved/processed_twitter_data.parquet` and `./Saved/processed_domain_data.parquet`
#
# > code is under `post_output/create_output.py`

# %%
import post_output.create_output as output
output.create_output()

# %% [markdown]
# **You can view final output here or in `/Output/output_0.csv`**

# %%
df = dd.read_parquet('./Saved/final_output.parquet')
# twitter_data = dd.read_parquet('./Saved/processed_twitter_data.parquet')
df.head(1)
# Out:
#                                      title author       date of publication  \
# id
# 002467b0-7a6c-5431-9cb1-013a79da4a23         None 2018-12-13 18:14:23+00:00
#
#                                                                              plain text  \
# id
# 002467b0-7a6c-5431-9cb1-013a79da4a23  Zones of influence in #Syria predict short-ter...
#
#                                          type citation url or text alias  \
# id
# 002467b0-7a6c-5431-9cb1-013a79da4a23  twitter                  ['@USIP']
#
#                                                              citation name  \
# id
# 002467b0-7a6c-5431-9cb1-013a79da4a23  ['United States Institute of Peace']
#
#                                      anchor text referring record id  \
# id
# 002467b0-7a6c-5431-9cb1-013a79da4a23          []                  []
#
#                                       number of referrals  \
# id
# 002467b0-7a6c-5431-9cb1-013a79da4a23                    0
#
#                                                                                     url  \
# id
# 002467b0-7a6c-5431-9cb1-013a79da4a23  https://twitter.com/ACMideast/status/107327998...
#
#                                      associated publisher  \
# id
# 002467b0-7a6c-5431-9cb1-013a79da4a23
#
#                                                              tags  \
# id
# 002467b0-7a6c-5431-9cb1-013a79da4a23  Think_Tank|||US|11-20||||||
#
#                                                   name
# id
# 002467b0-7a6c-5431-9cb1-013a79da4a23  Atlantic Council

# %%
df = dd.read_csv('./DataDomain/*.csv', engine='python', encoding='utf8', error_bad_lines=False)
df.head()
# Out:
# Skipping line 20: unexpected end of data
#                                      id  \
# 0  e44265d4-84a9-50d2-b07a-a9f88bbf027a
# 1  9b13dea8-5c68-5063-94c2-fbbf6ec10371
# 2  08a1c4ec-c4a8-52e4-a087-1bf973a8b011
# 3  cae61051-2672-5a49-8aae-f5c62d597344
# 4  2f0945d5-8593-5ff9-a041-b76cb188d1d2
#
#                                                title  \
# 0  Candidate for Lieutenant Governor Facing Scrut...
# 1  Bush Far Ahead of Democrats in Campaign Fund-R...
# 2       Taking ‘Oleanna’ into limbo (Published 2004)
# 3  A Force in the House, a Soft Voice Back Home; ...
# 4          The Week Ahead; POLITICS (Published 2004)
#
#                                                  url              author  \
# 0  https://www.nytimes.com/2002/08/10/nyregion/ca...  RICHARD PÉREZ-PEÑA
# 1  https://www.nytimes.com/2004/01/07/politics/ca...                  By
# 2  https://www.nytimes.com/2004/04/28/style/takin...                  By
# 3  https://www.nytimes.com/2002/07/05/nyregion/fo...                  By
# 4  https://www.nytimes.com/2004/04/11/weekinrevie...                 NaN
#
#                        date  \
# 0  2002-08-10T05:00:00.000Z
# 1  2004-01-07T05:00:00.000Z
# 2  2004-04-28T05:00:00.000Z
# 3  2002-07-05T05:00:00.000Z
# 4  2004-04-11T05:00:00.000Z
#
#                                         html_content  \
# 0  <div id="readability-page-1" class="page"><art...
# 1  <div id="readability-page-1" class="page"><div...
# 2  <div id="readability-page-1" class="page"><art...
# 3  <div id="readability-page-1" class="page"><art...
# 4  <div id="readability-page-1" class="page"><art...
#
#                                         article_text                   domain  \
# 0  Aug. 10, 2002See the article in its original c...  https://www.nytimes.com
# 1  Politics|Bush Far Ahead of Democrats in Campai...  https://www.nytimes.com
# 2  April 28, 2004LONDON—  David Mamet's short, sh...  https://www.nytimes.com
# 3  July 5, 2002See the article in its original co...  https://www.nytimes.com
# 4  April 11, 2004Annual meetings this week for tw...  https://www.nytimes.com
#
#                                           found_urls
# 0  [{'title': 'Skip to content', 'url': 'https://...
# 1  [{'title': 'Skip to content', 'url': 'https://...
# 2  [{'title': 'Skip to content', 'url': 'https://...
# 3  [{'title': 'Skip to content', 'url': 'https://...
# 4  [{'title': 'Skip to content', 'url': 'https://...
